# %%
import geopandas as gpd
shapefile = gpd.read_file("/Users/plakshakapoor/Downloads/tl_2016_us_zcta510/tl_2016_us_zcta510.shp")
print(shapefile)
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         43451   43451        B5   G6350          S   63411475    157689
# 1         43452   43452        B5   G6350          S  121783676  13437380
# 2         43456   43456        B5   G6350          S    9389362    999166
# 3         43457   43457        B5   G6350          S   48035540         0
# 4         43458   43458        B5   G6350          S    2573816     39915
# ...         ...     ...       ...     ...        ...        ...       ...
# 33139     84044   84044        B5   G6350          S  123500858  69912688
# 33140     84045   84045        B5   G6350          S   52750843    105247
# 33141     84046   84046        B5   G6350          S  333211822   4460752
# 33142     84047   84047        B5   G6350          S   16183011         0
# 33143     84049   84049        B5   G6350          S  215979976  10468874
#
#         INTPTLAT10    INTPTLON10  \
# 0      +41.3183010  -083.6174935
# 1      +41.5157923  -082.9809454
# 2      +41.6468445  -082.8226641
# 3      +41.2673266  -083.4274645
# 4      +41.5304461  -083.2133648
# ...            ...           ...
# 33139  +40.7201095  -112.1549645
# 33140  +40.3364908  -111.9111905
# 33141  +40.9207734  -109.8311030
# 33142  +40.6152290  -111.8907342
# 33143  +40.5233935  -111.5200098
#
#                                                 geometry
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...
# 1      POLYGON ((-83.06775 41.53772, -83.06773 41.539...
# 2      MULTIPOLYGON (((-82.85660 41.68122, -82.85683 ...
# 3      POLYGON ((-83.46747 41.26819, -83.46760 41.268...
# 4      POLYGON ((-83.22229 41.53102, -83.22228 41.532...
# ...                                                  ...
# 33139  POLYGON ((-112.13967 40.71672, -112.13818 40.7...
# 33140  MULTIPOLYGON (((-111.91876 40.17207, -111.9184...
# 33141  POLYGON ((-109.99995 40.99745, -109.99967 40.9...
# 33142  POLYGON ((-111.92069 40.61525, -111.92099 40.6...
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5...
#
# [33144 rows x 10 columns]

# %%
shapefile
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         43451   43451        B5   G6350          S   63411475    157689
# 1         43452   43452        B5   G6350          S  121783676  13437380
# 2         43456   43456        B5   G6350          S    9389362    999166
# 3         43457   43457        B5   G6350          S   48035540         0
# 4         43458   43458        B5   G6350          S    2573816     39915
# ...         ...     ...       ...     ...        ...        ...       ...
# 33139     84044   84044        B5   G6350          S  123500858  69912688
# 33140     84045   84045        B5   G6350          S   52750843    105247
# 33141     84046   84046        B5   G6350          S  333211822   4460752
# 33142     84047   84047        B5   G6350          S   16183011         0
# 33143     84049   84049        B5   G6350          S  215979976  10468874
#
#         INTPTLAT10    INTPTLON10  \
# 0      +41.3183010  -083.6174935
# 1      +41.5157923  -082.9809454
# 2      +41.6468445  -082.8226641
# 3      +41.2673266  -083.4274645
# 4      +41.5304461  -083.2133648
# ...            ...           ...
# 33139  +40.7201095  -112.1549645
# 33140  +40.3364908  -111.9111905
# 33141  +40.9207734  -109.8311030
# 33142  +40.6152290  -111.8907342
# 33143  +40.5233935  -111.5200098
#
#                                                 geometry
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...
# 1      POLYGON ((-83.06775 41.53772, -83.06773 41.539...
# 2      MULTIPOLYGON (((-82.85660 41.68122, -82.85683 ...
# 3      POLYGON ((-83.46747 41.26819, -83.46760 41.268...
# 4      POLYGON ((-83.22229 41.53102, -83.22228 41.532...
# ...                                                  ...
# 33139  POLYGON ((-112.13967 40.71672, -112.13818 40.7...
# 33140  MULTIPOLYGON (((-111.91876 40.17207, -111.9184...
# 33141  POLYGON ((-109.99995 40.99745, -109.99967 40.9...
# 33142  POLYGON ((-111.92069 40.61525, -111.92099 40.6...
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5...
#
# [33144 rows x 10 columns]

# %%
bounds = shapefile["geometry"].bounds

# %%
import pandas as pd
shapefile = pd.concat([shapefile,bounds], axis = 1)
# shapefile.append(bounds)

# %%
shapefile[shapefile["ZCTA5CE10"] == "10027"]
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10  ALAND10  AWATER10  \
# 12426     10027   10027        B5   G6350          S  2250649      1032
#
#         INTPTLAT10    INTPTLON10  \
# 12426  +40.8114075  -073.9530604
#
#                                                 geometry     minx       miny  \
# 12426  POLYGON ((-73.96169 40.81797, -73.96182 40.818... -73.9659  40.803047
#
#             maxx       maxy
# 12426 -73.940404  40.822108

# %%
shapefile
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         43451   43451        B5   G6350          S   63411475    157689
# 1         43452   43452        B5   G6350          S  121783676  13437380
# 2         43456   43456        B5   G6350          S    9389362    999166
# 3         43457   43457        B5   G6350          S   48035540         0
# 4         43458   43458        B5   G6350          S    2573816     39915
# ...         ...     ...       ...     ...        ...        ...       ...
# 33139     84044   84044        B5   G6350          S  123500858  69912688
# 33140     84045   84045        B5   G6350          S   52750843    105247
# 33141     84046   84046        B5   G6350          S  333211822   4460752
# 33142     84047   84047        B5   G6350          S   16183011         0
# 33143     84049   84049        B5   G6350          S  215979976  10468874
#
#         INTPTLAT10    INTPTLON10  \
# 0      +41.3183010  -083.6174935
# 1      +41.5157923  -082.9809454
# 2      +41.6468445  -082.8226641
# 3      +41.2673266  -083.4274645
# 4      +41.5304461  -083.2133648
# ...            ...           ...
# 33139  +40.7201095  -112.1549645
# 33140  +40.3364908  -111.9111905
# 33141  +40.9207734  -109.8311030
# 33142  +40.6152290  -111.8907342
# 33143  +40.5233935  -111.5200098
#
#                                                 geometry        minx  \
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 1      POLYGON ((-83.06775 41.53772, -83.06773 41.539...  -83.086978
# 2      MULTIPOLYGON (((-82.85660 41.68122, -82.85683 ...  -82.856831
# 3      POLYGON ((-83.46747 41.26819, -83.46760 41.268...  -83.496503
# 4      POLYGON ((-83.22229 41.53102, -83.22228 41.532...  -83.222294
# ...                                                  ...         ...
# 33139  POLYGON ((-112.13967 40.71672, -112.13818 40.7... -112.260216
# 33140  MULTIPOLYGON (((-111.91876 40.17207, -111.9184... -111.964453
# 33141  POLYGON ((-109.99995 40.99745, -109.99967 40.9... -110.000717
# 33142  POLYGON ((-111.92069 40.61525, -111.92099 40.6... -111.921409
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
#
#             miny        maxx       maxy
# 0      41.268471  -83.533770  41.348933
# 1      41.457169  -82.812284  41.588249
# 2      41.628140  -82.793069  41.724549
# 3      41.239110  -83.359708  41.298088
# 4      41.523729  -83.202862  41.538385
# ...          ...         ...        ...
# 33139  40.628011 -112.042451  40.848160
# 33140  40.168441 -111.846438  40.420687
# 33141  40.841999 -109.578130  40.999044
# 33142  40.587915 -111.846833  40.631704
# 33143  40.405364 -111.425687  40.640143
#
# [33144 rows x 14 columns]

# %%
lat_long_list = []

# %%
# def createZoneTable(zone_factor,westlimit=-74.2635, southlimit=40.4856, eastlimit=-73.7526, northlimit=40.9596):

def createZoneTable(zone_factor,westlimit, southlimit, eastlimit, northlimit):
    zone_table = list()
    #Your code goes here
    zone_lat_diff = (northlimit - southlimit)/zone_factor
    zone_long_diff = (abs(westlimit - eastlimit))/zone_factor
#     print(zone_lat_diff,zone_long_diff)
    init_long = westlimit
    init_lat = southlimit
#     print(init_long + zone_long_diff)
#     print(init_lat + zone_lat_diff)
    counter = 0 
    total_list = []
    for i in range(0,zone_factor*zone_factor):

        row_long_new = init_long + zone_long_diff
        row_lat_new_constant = init_lat + zone_lat_diff
        
        first_coordinate = (init_long, init_lat)
        second_coordinate = (row_long_new, init_lat)
        
        third_coordinate = (row_long_new,row_lat_new_constant)
        fourth_coordinate = (init_long , row_lat_new_constant)
        fifth_coordinate = first_coordinate
        
        
        
        
        zone_list = [first_coordinate, second_coordinate, third_coordinate, fourth_coordinate, fifth_coordinate]

        zone_list_map = (zone_list)
        counter = counter + 1
        if(counter % zone_factor == 0):
            init_lat = init_lat + zone_lat_diff
            init_long = westlimit
        else:
            init_long = row_long_new
#         total_list.append(zone_list_map)
        total_list.extend(zone_list)
        lat_long_list.extend(zone_list)

    
    return total_list

# %%
shapefile.columns
# Out:
# Index(['ZCTA5CE10', 'GEOID10', 'CLASSFP10', 'MTFCC10', 'FUNCSTAT10', 'ALAND10',
#        'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'geometry', 'minx', 'miny',
#        'maxx', 'maxy'],
#       dtype='object')

# %%
df_pop = pd.read_csv("/Users/plakshakapoor/Downloads/simplemaps_uszips_basicv1.78/uszips.csv")
df_pop_zcta = df_pop[df_pop["zcta"] == True]

# %%
import numpy as np
df_pop_zcta["density_log"] = np.log(df_pop_zcta['density'])
import matplotlib.pyplot as plt
plt.hist(df_pop_zcta['density'], log=True)
# Out:
# /Users/plakshakapoor/opt/anaconda3/envs/kiwi/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (array([3.2672e+04, 2.6900e+02, 5.9000e+01, 3.8000e+01, 2.0000e+01,
#         1.6000e+01, 1.0000e+01, 4.0000e+00, 8.0000e+00, 1.0000e+00]),
#  array([    0.  ,  5764.11, 11528.22, 17292.33, 23056.44, 28820.55,
#         34584.66, 40348.77, 46112.88, 51876.99, 57641.1 ]),
#  <BarContainer object of 10 artists>)

# %%
# merge["ZCTA5CE10_int"] = merge["ZCTA5CE10"].astype(str).astype(int)
# merge.dtypes

# %%
df_pop_zcta["zip"] = df_pop_zcta["zip"].astype(str)
df_pop_zcta["zip"] = df_pop_zcta["zip"].astype(str).str.pad(5,fillchar='0')
# .astype(int)
df_pop_zcta.dtypes
# Out:
# zip                  object
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population          float64
# density             float64
# county_fips           int64
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# density_log         float64
# dtype: object

# %%
shapefile
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         43451   43451        B5   G6350          S   63411475    157689
# 1         43452   43452        B5   G6350          S  121783676  13437380
# 2         43456   43456        B5   G6350          S    9389362    999166
# 3         43457   43457        B5   G6350          S   48035540         0
# 4         43458   43458        B5   G6350          S    2573816     39915
# ...         ...     ...       ...     ...        ...        ...       ...
# 33139     84044   84044        B5   G6350          S  123500858  69912688
# 33140     84045   84045        B5   G6350          S   52750843    105247
# 33141     84046   84046        B5   G6350          S  333211822   4460752
# 33142     84047   84047        B5   G6350          S   16183011         0
# 33143     84049   84049        B5   G6350          S  215979976  10468874
#
#         INTPTLAT10    INTPTLON10  \
# 0      +41.3183010  -083.6174935
# 1      +41.5157923  -082.9809454
# 2      +41.6468445  -082.8226641
# 3      +41.2673266  -083.4274645
# 4      +41.5304461  -083.2133648
# ...            ...           ...
# 33139  +40.7201095  -112.1549645
# 33140  +40.3364908  -111.9111905
# 33141  +40.9207734  -109.8311030
# 33142  +40.6152290  -111.8907342
# 33143  +40.5233935  -111.5200098
#
#                                                 geometry        minx  \
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 1      POLYGON ((-83.06775 41.53772, -83.06773 41.539...  -83.086978
# 2      MULTIPOLYGON (((-82.85660 41.68122, -82.85683 ...  -82.856831
# 3      POLYGON ((-83.46747 41.26819, -83.46760 41.268...  -83.496503
# 4      POLYGON ((-83.22229 41.53102, -83.22228 41.532...  -83.222294
# ...                                                  ...         ...
# 33139  POLYGON ((-112.13967 40.71672, -112.13818 40.7... -112.260216
# 33140  MULTIPOLYGON (((-111.91876 40.17207, -111.9184... -111.964453
# 33141  POLYGON ((-109.99995 40.99745, -109.99967 40.9... -110.000717
# 33142  POLYGON ((-111.92069 40.61525, -111.92099 40.6... -111.921409
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
#
#             miny        maxx       maxy
# 0      41.268471  -83.533770  41.348933
# 1      41.457169  -82.812284  41.588249
# 2      41.628140  -82.793069  41.724549
# 3      41.239110  -83.359708  41.298088
# 4      41.523729  -83.202862  41.538385
# ...          ...         ...        ...
# 33139  40.628011 -112.042451  40.848160
# 33140  40.168441 -111.846438  40.420687
# 33141  40.841999 -109.578130  40.999044
# 33142  40.587915 -111.846833  40.631704
# 33143  40.405364 -111.425687  40.640143
#
# [33144 rows x 14 columns]

# %%
df_pop_zcta['density_cut'] = pd.qcut(df_pop_zcta['density'], q=10, labels=False)
# df = df.assign(Quartile=quartiles.values)

# %%
shapefile_join_popDen = pd.merge(shapefile, df_pop_zcta,how="left", left_on=shapefile["ZCTA5CE10"], right_on=df_pop_zcta["zip"])
shapefile_join_popDen
shapefile_join_popDen_notnull = shapefile_join_popDen[shapefile_join_popDen["zip"].notnull()]
# merge_join_popDen_notnull = merge_join_popDen[merge_join_popDen["zip"].notnull()]

# %%
shapefile_join_popDen_notnull["density_cut"].value_counts()
# Out:
# 0.0    3395
# 4.0    3316
# 1.0    3313
# 7.0    3310
# 9.0    3310
# 8.0    3309
# 6.0    3307
# 5.0    3304
# 3.0    3269
# 2.0    3264
# Name: density_cut, dtype: int64

# %%
shapefile_join_popDen_notnull[shapefile_join_popDen_notnull["ZCTA5CE10"]=="84108"]
# Out:
#        key_0 ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 11581  84108     84108   84108        B5   G6350          S  177976042
#
#        AWATER10   INTPTLAT10    INTPTLON10  ... county_fips  county_name  \
# 11581    381009  +40.8085034  -111.7290433  ...     49035.0    Salt Lake
#
#          county_weights  county_names_all  county_fips_all imprecise  \
# 11581  {"49035": "100"}         Salt Lake            49035     False
#
#        military        timezone density_log density_cut
# 11581     False  America/Denver    4.833102         6.0
#
# [1 rows x 35 columns]

# %%
shapefile_join_popDen_notnull[shapefile_join_popDen_notnull["density_cut"]<=4.0][["ZCTA5CE10","state_name","density_cut"]]
# Out:
#       ZCTA5CE10 state_name  density_cut
# 0         43451       Ohio          4.0
# 6         43462       Ohio          3.0
# 8         43464       Ohio          3.0
# 10        43466       Ohio          4.0
# 13        97824     Oregon          1.0
# ...         ...        ...          ...
# 33131     84036       Utah          2.0
# 33133     84038       Utah          1.0
# 33134     84039       Utah          1.0
# 33141     84046       Utah          0.0
# 33143     84049       Utah          4.0
#
# [16557 rows x 3 columns]

# %%
shapefile_join_popDen_notnull.columns
# Out:
# Index(['key_0', 'ZCTA5CE10', 'GEOID10', 'CLASSFP10', 'MTFCC10', 'FUNCSTAT10',
#        'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'geometry', 'minx',
#        'miny', 'maxx', 'maxy', 'zip', 'lat', 'lng', 'city', 'state_id',
#        'state_name', 'zcta', 'parent_zcta', 'population', 'density',
#        'county_fips', 'county_name', 'county_weights', 'county_names_all',
#        'county_fips_all', 'imprecise', 'military', 'timezone', 'density_log',
#        'density_cut'],
#       dtype='object')

# %%
shapefile_join_popDen_notnull[shapefile_join_popDen_notnull["density"].isnull()]
# Out:
#        key_0 ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 4763   00831     00831   00831        B5   G6350          S     119891
# 4764   00840     00840   00840        B5   G6350          S   48724800
# 4765   00841     00841   00841        B5   G6350          S    6600893
# 4766   00850     00850   00850        B5   G6350          S   60060282
# 4767   00851     00851   00851        B5   G6350          S   19685283
# 4768   96910     96910   96910        B5   G6350          S   39144820
# 4769   96913     96913   96913        B5   G6350          S   63776792
# 4770   96915     96915   96915        B5   G6350          S  212399590
# 4771   96916     96916   96916        B5   G6350          S    8146159
# 4772   96917     96917   96917        B5   G6350          S   46482180
# 4773   96921     96921   96921        B5   G6350          S     469596
# 4774   96928     96928   96928        B5   G6350          S    1189070
# 4775   96929     96929   96929        B5   G6350          S  171450550
# 5602   96932     96932   96932        B5   G6350          S     499553
# 13501  96950     96950   96950        B5   G6350          S  118883306
# 13502  96951     96951   96951        B5   G6350          S   85098741
# 13503  96952     96952   96952        B5   G6350          S  101224486
# 13504  96799     96799   96799        B5   G6350          S  197672934
# 13505  00801     00801   00801        B5   G6350          S    2875853
# 13506  00802     00802   00802        B5   G6350          S   71671243
# 13507  00820     00820   00820        B5   G6350          S   78982024
# 13508  00823     00823   00823        B5   G6350          S    1035362
# 13509  00824     00824   00824        B5   G6350          S      57053
# 13510  00830     00830   00830        B5   G6350          S   50003826
#
#        AWATER10   INTPTLAT10    INTPTLON10  ... county_fips  county_name  \
# 4763          0  +18.3272939  -064.7867198  ...     78020.0     St. John
# 4764      22578  +17.7478722  -064.8806949  ...     78010.0    St. Croix
# 4765     632642  +17.7681345  -064.8078517  ...     78010.0    St. Croix
# 4766    3028705  +17.7052534  -064.7525564  ...     78010.0    St. Croix
# 4767      71124  +17.7322277  -064.7707604  ...     78010.0    St. Croix
# 4768     137543  +13.4505692  +144.7507227  ...     66010.0         Guam
# 4769          0  +13.4778382  +144.8145190  ...     66010.0         Guam
# 4770   16628595  +13.3774806  +144.7022783  ...     66010.0         Guam
# 4771          0  +13.2603723  +144.7006789  ...     66010.0         Guam
# 4772     125441  +13.3009464  +144.7398106  ...     66010.0         Guam
# 4773          0  +13.4591223  +144.7940327  ...     66010.0         Guam
# 4774       2939  +13.3845367  +144.6612982  ...     66010.0         Guam
# 4775          0  +13.5650982  +144.8762401  ...     66010.0         Guam
# 5602          0  +13.4754276  +144.7417503  ...     66010.0         Guam
# 13501    185857  +15.1868936  +145.7543957  ...     69110.0       Saipan
# 13502     19201  +14.1524934  +145.2129037  ...     69100.0         Rota
# 13503    727567  +15.0097681  +145.6211273  ...     69120.0       Tinian
# 13504   1164503  -14.3233846  -170.7502395  ...     60050.0      Western
# 13505      1354  +18.3498707  -064.9740158  ...     78030.0   St. Thomas
# 13506   8928497  +18.3407091  -064.9233287  ...     78030.0   St. Thomas
# 13507   3075492  +17.7431002  -064.6865559  ...     78010.0    St. Croix
# 13508         0  +17.7235479  -064.7459318  ...     78010.0    St. Croix
# 13509         0  +17.7445568  -064.6829328  ...     78010.0    St. Croix
# 13510    374670  +18.3385589  -064.7365301  ...     78020.0     St. John
#
#                                           county_weights  \
# 4763                                      {"78020": 100}
# 4764                                      {"78010": 100}
# 4765                                      {"78010": 100}
# 4766                                      {"78010": 100}
# 4767                                      {"78010": 100}
# 4768                                      {"66010": 100}
# 4769                                      {"66010": 100}
# 4770                                      {"66010": 100}
# 4771                                      {"66010": 100}
# 4772                                      {"66010": 100}
# 4773                                      {"66010": 100}
# 4774                                      {"66010": 100}
# 4775                                      {"66010": 100}
# 5602                                      {"66010": 100}
# 13501                                     {"69110": 100}
# 13502                                     {"69100": 100}
# 13503                                     {"69120": 100}
# 13504  {"60050": 36.38, "60010": 32.64, "60020": 29.2...
# 13505                                     {"78030": 100}
# 13506                                     {"78030": 100}
# 13507                                     {"78010": 100}
# 13508                                     {"78010": 100}
# 13509                                     {"78010": 100}
# 13510                                     {"78020": 100}
#
#                            county_names_all          county_fips_all  \
# 4763                               St. John                    78020
# 4764                              St. Croix                    78010
# 4765                              St. Croix                    78010
# 4766                              St. Croix                    78010
# 4767                              St. Croix                    78010
# 4768                                   Guam                    66010
# 4769                                   Guam                    66010
# 4770                                   Guam                    66010
# 4771                                   Guam                    66010
# 4772                                   Guam                    66010
# 4773                                   Guam                    66010
# 4774                                   Guam                    66010
# 4775                                   Guam                    66010
# 5602                                   Guam                    66010
# 13501                                Saipan                    69110
# 13502                                  Rota                    69100
# 13503                                Tinian                    69120
# 13504  Western|Eastern|Manu'a|Swains Island  60050|60010|60020|60040
# 13505                            St. Thomas                    78030
# 13506                            St. Thomas                    78030
# 13507                             St. Croix                    78010
# 13508                             St. Croix                    78010
# 13509                             St. Croix                    78010
# 13510                              St. John                    78020
#
#       imprecise  military           timezone density_log density_cut
# 4763      False     False  America/St_Thomas         NaN         NaN
# 4764      False     False  America/St_Thomas         NaN         NaN
# 4765      False     False  America/St_Thomas         NaN         NaN
# 4766      False     False  America/St_Thomas         NaN         NaN
# 4767      False     False  America/St_Thomas         NaN         NaN
# 4768      False     False       Pacific/Guam         NaN         NaN
# 4769      False     False       Pacific/Guam         NaN         NaN
# 4770      False     False       Pacific/Guam         NaN         NaN
# 4771      False     False       Pacific/Guam         NaN         NaN
# 4772      False     False       Pacific/Guam         NaN         NaN
# 4773      False     False       Pacific/Guam         NaN         NaN
# 4774      False     False       Pacific/Guam         NaN         NaN
# 4775      False     False       Pacific/Guam         NaN         NaN
# 5602      False     False       Pacific/Guam         NaN         NaN
# 13501     False     False     Pacific/Saipan         NaN         NaN
# 13502     False     False     Pacific/Saipan         NaN         NaN
# 13503     False     False     Pacific/Saipan         NaN         NaN
# 13504     False     False  Pacific/Pago_Pago         NaN         NaN
# 13505     False     False  America/St_Thomas         NaN         NaN
# 13506     False     False  America/St_Thomas         NaN         NaN
# 13507     False     False  America/St_Thomas         NaN         NaN
# 13508     False     False  America/St_Thomas         NaN         NaN
# 13509     False     False  America/St_Thomas         NaN         NaN
# 13510     False     False  America/St_Thomas         NaN         NaN
#
# [24 rows x 35 columns]

# %%
shapefile_join_popDen_notnull["density_cut"].value_counts(dropna=False)
# Out:
# 0.0    3395
# 4.0    3316
# 1.0    3313
# 7.0    3310
# 9.0    3310
# 8.0    3309
# 6.0    3307
# 5.0    3304
# 3.0    3269
# 2.0    3264
# NaN      24
# Name: density_cut, dtype: int64

# %%
shapefile_join_popDen_notnull["density_cut"].value_counts(dropna=False)
# Out:
# 0.0    3395
# 4.0    3316
# 1.0    3313
# 7.0    3310
# 9.0    3310
# 8.0    3309
# 6.0    3307
# 5.0    3304
# 3.0    3269
# 2.0    3264
# NaN      24
# Name: density_cut, dtype: int64

# %%
shapefile_join_popDen_notnull
# Out:
#        key_0 ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0      43451     43451   43451        B5   G6350          S   63411475
# 1      43452     43452   43452        B5   G6350          S  121783676
# 2      43456     43456   43456        B5   G6350          S    9389362
# 3      43457     43457   43457        B5   G6350          S   48035540
# 4      43458     43458   43458        B5   G6350          S    2573816
# ...      ...       ...     ...       ...     ...        ...        ...
# 33139  84044     84044   84044        B5   G6350          S  123500858
# 33140  84045     84045   84045        B5   G6350          S   52750843
# 33141  84046     84046   84046        B5   G6350          S  333211822
# 33142  84047     84047   84047        B5   G6350          S   16183011
# 33143  84049     84049   84049        B5   G6350          S  215979976
#
#        AWATER10   INTPTLAT10    INTPTLON10  ... county_fips  county_name  \
# 0        157689  +41.3183010  -083.6174935  ...     39173.0         Wood
# 1      13437380  +41.5157923  -082.9809454  ...     39123.0       Ottawa
# 2        999166  +41.6468445  -082.8226641  ...     39123.0       Ottawa
# 3             0  +41.2673266  -083.4274645  ...     39173.0         Wood
# 4         39915  +41.5304461  -083.2133648  ...     39123.0       Ottawa
# ...         ...          ...           ...  ...         ...          ...
# 33139  69912688  +40.7201095  -112.1549645  ...     49035.0    Salt Lake
# 33140    105247  +40.3364908  -111.9111905  ...     49049.0         Utah
# 33141   4460752  +40.9207734  -109.8311030  ...     49009.0      Daggett
# 33142         0  +40.6152290  -111.8907342  ...     49035.0    Salt Lake
# 33143  10468874  +40.5233935  -111.5200098  ...     49051.0      Wasatch
#
#                                           county_weights  \
# 0                                       {"39173": "100"}
# 1                                       {"39123": "100"}
# 2                                       {"39123": "100"}
# 3      {"39173": "73.35", "39143": "24.38", "39147": ...
# 4                                       {"39123": "100"}
# ...                                                  ...
# 33139                                   {"49035": "100"}
# 33140                                   {"49049": "100"}
# 33141                                   {"49009": "100"}
# 33142                                   {"49035": "100"}
# 33143                                   {"49051": "100"}
#
#            county_names_all    county_fips_all imprecise  military  \
# 0                      Wood              39173     False     False
# 1                    Ottawa              39123     False     False
# 2                    Ottawa              39123     False     False
# 3      Wood|Sandusky|Seneca  39173|39143|39147     False     False
# 4                    Ottawa              39123     False     False
# ...                     ...                ...       ...       ...
# 33139             Salt Lake              49035     False     False
# 33140                  Utah              49049     False     False
# 33141               Daggett              49009     False     False
# 33142             Salt Lake              49035     False     False
# 33143               Wasatch              49051     False     False
#
#                timezone density_log density_cut
# 0      America/New_York    2.975530         4.0
# 1      America/New_York    4.729156         6.0
# 2      America/New_York    3.756538         5.0
# 3      America/New_York    3.433987         5.0
# 4      America/New_York    5.007965         6.0
# ...                 ...         ...         ...
# 33139    America/Denver    5.394536         7.0
# 33140    America/Denver    6.306640         8.0
# 33141    America/Denver    0.182322         0.0
# 33142    America/Denver    7.634579         9.0
# 33143    America/Denver    3.292126         4.0
#
# [33121 rows x 35 columns]

# %%
shapefile_join_popDen_notnull_density = shapefile_join_popDen_notnull[shapefile_join_popDen_notnull["density_cut"].notnull()]

# %%
shapefile_join_popDen_notnull_density["density_cut"] = shapefile_join_popDen_notnull_density["density_cut"].astype(int)
# Out:
# /Users/plakshakapoor/opt/anaconda3/envs/kiwi/lib/python3.6/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
shapefile_join_popDen_notnull_density["density_cut"] = shapefile_join_popDen_notnull_density["density_cut"] + 5
shapefile_join_popDen_notnull_density["density_cut"].value_counts()
# Out:
# 5     3395
# 9     3316
# 6     3313
# 14    3310
# 12    3310
# 13    3309
# 11    3307
# 10    3304
# 8     3269
# 7     3264
# Name: density_cut, dtype: int64

# %%
shapefile_join_popDen_notnull_density["new_col"] = shapefile_join_popDen_notnull_density.apply(lambda row: createZoneTable(row["density_cut"], row["minx"], row["miny"], row["maxx"], row["maxy"]), axis=1)
# shapefile_join_popDen_notnull_density["new_col"] = shapefile_join_popDen_notnull_density.apply(lambda row: createZoneTable(10, row["minx"], row["miny"], row["maxx"], row["maxy"]), axis=1)

list_of_latlong = shapefile_join_popDen_notnull_density["new_col"].to_list()

# %%
list_of_latlong
flat_list = [item for sublist in list_of_latlong for item in sublist]
len(flat_list)
# Out:
# 16285295

# %%
shapefile_join_popDen_notnull_density
# Out:
#        key_0 ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0      43451     43451   43451        B5   G6350          S   63411475
# 1      43452     43452   43452        B5   G6350          S  121783676
# 2      43456     43456   43456        B5   G6350          S    9389362
# 3      43457     43457   43457        B5   G6350          S   48035540
# 4      43458     43458   43458        B5   G6350          S    2573816
# ...      ...       ...     ...       ...     ...        ...        ...
# 33139  84044     84044   84044        B5   G6350          S  123500858
# 33140  84045     84045   84045        B5   G6350          S   52750843
# 33141  84046     84046   84046        B5   G6350          S  333211822
# 33142  84047     84047   84047        B5   G6350          S   16183011
# 33143  84049     84049   84049        B5   G6350          S  215979976
#
#        AWATER10   INTPTLAT10    INTPTLON10  ... county_name  \
# 0        157689  +41.3183010  -083.6174935  ...        Wood
# 1      13437380  +41.5157923  -082.9809454  ...      Ottawa
# 2        999166  +41.6468445  -082.8226641  ...      Ottawa
# 3             0  +41.2673266  -083.4274645  ...        Wood
# 4         39915  +41.5304461  -083.2133648  ...      Ottawa
# ...         ...          ...           ...  ...         ...
# 33139  69912688  +40.7201095  -112.1549645  ...   Salt Lake
# 33140    105247  +40.3364908  -111.9111905  ...        Utah
# 33141   4460752  +40.9207734  -109.8311030  ...     Daggett
# 33142         0  +40.6152290  -111.8907342  ...   Salt Lake
# 33143  10468874  +40.5233935  -111.5200098  ...     Wasatch
#
#                                           county_weights  \
# 0                                       {"39173": "100"}
# 1                                       {"39123": "100"}
# 2                                       {"39123": "100"}
# 3      {"39173": "73.35", "39143": "24.38", "39147": ...
# 4                                       {"39123": "100"}
# ...                                                  ...
# 33139                                   {"49035": "100"}
# 33140                                   {"49049": "100"}
# 33141                                   {"49009": "100"}
# 33142                                   {"49035": "100"}
# 33143                                   {"49051": "100"}
#
#            county_names_all    county_fips_all  imprecise military  \
# 0                      Wood              39173      False    False
# 1                    Ottawa              39123      False    False
# 2                    Ottawa              39123      False    False
# 3      Wood|Sandusky|Seneca  39173|39143|39147      False    False
# 4                    Ottawa              39123      False    False
# ...                     ...                ...        ...      ...
# 33139             Salt Lake              49035      False    False
# 33140                  Utah              49049      False    False
# 33141               Daggett              49009      False    False
# 33142             Salt Lake              49035      False    False
# 33143               Wasatch              49051      False    False
#
#                timezone  density_log density_cut  \
# 0      America/New_York     2.975530           9
# 1      America/New_York     4.729156          11
# 2      America/New_York     3.756538          10
# 3      America/New_York     3.433987          10
# 4      America/New_York     5.007965          11
# ...                 ...          ...         ...
# 33139    America/Denver     5.394536          12
# 33140    America/Denver     6.306640          13
# 33141    America/Denver     0.182322           5
# 33142    America/Denver     7.634579          14
# 33143    America/Denver     3.292126           9
#
#                                                  new_col
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...
# 1      [(-83.086978, 41.457169), (-83.06200581818182,...
# 2      [(-82.856831, 41.628139999999995), (-82.850454...
# 3      [(-83.49650299999999, 41.23911), (-83.4828235,...
# 4      [(-83.22229399999999, 41.523728999999996), (-8...
# ...                                                  ...
# 33139  [(-112.260216, 40.628011), (-112.2420689166666...
# 33140  [(-111.96445299999999, 40.168441), (-111.95537...
# 33141  [(-110.000717, 40.841999), (-109.9161996, 40.8...
# 33142  [(-111.921409, 40.587914999999995), (-111.9160...
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...
#
# [33097 rows x 36 columns]

# %%
df_coordinates = pd.DataFrame(flat_list, columns =['long', 'lat'])
df_coordinates
# Out:
#                 long        lat
# 0         -83.708733  41.268471
# 1         -83.689293  41.268471
# 2         -83.689293  41.277411
# 3         -83.708733  41.277411
# 4         -83.708733  41.268471
# ...              ...        ...
# 16285290 -111.444382  40.614056
# 16285291 -111.425687  40.614056
# 16285292 -111.425687  40.640143
# 16285293 -111.444382  40.640143
# 16285294 -111.444382  40.614056
#
# [16285295 rows x 2 columns]

# %%
df_coordinates = df_coordinates.drop_duplicates()
df_coordinates
# Out:
#                 long        lat
# 0         -83.708733  41.268471
# 1         -83.689293  41.268471
# 2         -83.689293  41.277411
# 3         -83.708733  41.277411
# 6         -83.669852  41.268471
# ...              ...        ...
# 16285272 -111.500467  40.640143
# 16285277 -111.481772  40.640143
# 16285282 -111.463077  40.640143
# 16285287 -111.444382  40.640143
# 16285292 -111.425687  40.640143
#
# [3918538 rows x 2 columns]

# %%
shapefile.columns
# Out:
# Index(['ZCTA5CE10', 'GEOID10', 'CLASSFP10', 'MTFCC10', 'FUNCSTAT10', 'ALAND10',
#        'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'geometry', 'minx', 'miny',
#        'maxx', 'maxy'],
#       dtype='object')

# %%
shapefile_join_popDen_notnull_density.columns
# Out:
# Index(['key_0', 'ZCTA5CE10', 'GEOID10', 'CLASSFP10', 'MTFCC10', 'FUNCSTAT10',
#        'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'geometry', 'minx',
#        'miny', 'maxx', 'maxy', 'zip', 'lat', 'lng', 'city', 'state_id',
#        'state_name', 'zcta', 'parent_zcta', 'population', 'density',
#        'county_fips', 'county_name', 'county_weights', 'county_names_all',
#        'county_fips_all', 'imprecise', 'military', 'timezone', 'density_log',
#        'density_cut', 'new_col'],
#       dtype='object')

# %%
shapefile.shape
# Out:
# (33144, 14)

# %%
shapefile_join_popDen_notnull_density.shape
# Out:
# (33097, 36)

# %%
shapefile_with_density = shapefile_join_popDen_notnull_density[['ZCTA5CE10', 'GEOID10', 'CLASSFP10', 'MTFCC10', 'FUNCSTAT10',
       'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'geometry', 'minx',
       'miny', 'maxx', 'maxy','density_cut','new_col']]

# %%
gdf = gpd.GeoDataFrame(df_coordinates, geometry=gpd.points_from_xy(df_coordinates['long'], df_coordinates['lat']))
gdf

from shapely.geometry import shape, Point

merge = gpd.sjoin(shapefile_with_density, gdf, how="inner", op='contains')
# Out:
# /Users/plakshakapoor/opt/anaconda3/envs/kiwi/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4269
# Right CRS: None

# %%
merge
# Out:
#       ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0         43451   43451        B5   G6350          S   63411475    157689
# 0         43451   43451        B5   G6350          S   63411475    157689
# 0         43451   43451        B5   G6350          S   63411475    157689
# 0         43451   43451        B5   G6350          S   63411475    157689
# 0         43451   43451        B5   G6350          S   63411475    157689
# ...         ...     ...       ...     ...        ...        ...       ...
# 33143     84049   84049        B5   G6350          S  215979976  10468874
# 33143     84049   84049        B5   G6350          S  215979976  10468874
# 33143     84049   84049        B5   G6350          S  215979976  10468874
# 33143     84049   84049        B5   G6350          S  215979976  10468874
# 33143     84049   84049        B5   G6350          S  215979976  10468874
#
#         INTPTLAT10    INTPTLON10  \
# 0      +41.3183010  -083.6174935
# 0      +41.3183010  -083.6174935
# 0      +41.3183010  -083.6174935
# 0      +41.3183010  -083.6174935
# 0      +41.3183010  -083.6174935
# ...            ...           ...
# 33143  +40.5233935  -111.5200098
# 33143  +40.5233935  -111.5200098
# 33143  +40.5233935  -111.5200098
# 33143  +40.5233935  -111.5200098
# 33143  +40.5233935  -111.5200098
#
#                                                 geometry        minx  \
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# 0      POLYGON ((-83.67446 41.33112, -83.67444 41.331...  -83.708733
# ...                                                  ...         ...
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
# 33143  POLYGON ((-111.57068 40.53346, -111.57051 40.5... -111.593942
#
#             miny        maxx       maxy  density_cut  \
# 0      41.268471  -83.533770  41.348933            9
# 0      41.268471  -83.533770  41.348933            9
# 0      41.268471  -83.533770  41.348933            9
# 0      41.268471  -83.533770  41.348933            9
# 0      41.268471  -83.533770  41.348933            9
# ...          ...         ...        ...          ...
# 33143  40.405364 -111.425687  40.640143            9
# 33143  40.405364 -111.425687  40.640143            9
# 33143  40.405364 -111.425687  40.640143            9
# 33143  40.405364 -111.425687  40.640143            9
# 33143  40.405364 -111.425687  40.640143            9
#
#                                                  new_col  index_right  \
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...     11609431
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...     11609416
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...     11609411
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...     11609421
# 0      [(-83.708733, 41.268471), (-83.68929266666666,...     11609426
# ...                                                  ...          ...
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...       878867
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...       878927
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...       878922
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...      5816102
# 33143  [(-111.593942, 40.405364), (-111.575247, 40.40...       878877
#
#              long        lat
# 0      -83.538575  41.305192
# 0      -83.618946  41.305192
# 0      -83.645737  41.305192
# 0      -83.592156  41.305192
# 0      -83.565366  41.305192
# ...           ...        ...
# 33143 -111.539311  40.410321
# 33143 -111.513951  40.431440
# 33143 -111.539311  40.431440
# 33143 -111.505847  40.424182
# 33143 -111.488591  40.410321
#
# [3780389 rows x 19 columns]

# %%
# merge["ZCTA5CE10"] = merge["ZCTA5CE10"].astype(str).str.pad(5,fillchar='0')

# %%
# merge[merge["ZCTA5CE10"]=="00820"]

# %%
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(100, 100))
# #     figsize=(100,60))
# street_map = gpd.read_file("/Users/plakshakapoor/Downloads/s_11au16/s_11au16.shp")
# street_map.plot(ax=ax,alpha=0.4,color="red", figsize=(100, 100))
# merge.plot(ax=ax,alpha=0.5, legend=True, markersize=1, figsize=(100, 100))
# plt.show()

# %%
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(10, 10))
# #     figsize=(100,60))
# street_map = gpd.read_file("/Users/plakshakapoor/Downloads/s_11au16/s_11au16.shp")
# street_map.plot(ax=ax,alpha=0.4,color="red", figsize=(10, 10))
# merge.plot(ax=ax,alpha=0.5, legend=True, markersize=1, figsize=(100, 100))
# plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
#     figsize=(100,60))
street_map = gpd.read_file("/Users/plakshakapoor/Downloads/s_11au16/s_11au16.shp")
# street_map.plot(ax=ax,alpha=0.4,color="red", figsize=(10, 10))
merge[merge["ZCTA5CE10"]=="10027"].plot(ax=ax,alpha=0.5, legend=True, markersize=1, figsize=(100, 100))
plt.show()

# %%
merge[merge["ZCTA5CE10"]=="43451"].plot()
# Out:
# <AxesSubplot:>

# %%
def check_in(tup, lst):
    return tup in lst

# %%
# merge.iloc[0]["combined_lat_log"] in merge.iloc[0]["new_col"]

# %%
# merge[["new_col","long","lat"]]
merge["combined_lat_log"] = list(zip(merge.long, merge.lat))
merge["tup_in_list"] = merge.apply(lambda row: check_in(row["combined_lat_log"], row["new_col"]), axis=1)

# %%
merge_filtered = merge[merge["tup_in_list"]==True]

# %%
import matplotlib.pyplot as plt
plt.scatter(x=merge_filtered[merge_filtered["ZCTA5CE10"]=="10027"]['long'], y=merge_filtered[merge_filtered["ZCTA5CE10"]=="10027"]['lat'], s=10)
plt.show()

# %%
merge_filtered[merge_filtered["ZCTA5CE10"]=="10027"].plot()
# Out:
# <AxesSubplot:>

# %%
merge_filtered[merge_filtered["ZCTA5CE10"]=="43451"].plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.scatter(x=merge_filtered[merge_filtered["ZCTA5CE10"]=="43451"]['long'], y=merge_filtered[merge_filtered["ZCTA5CE10"]=="43451"]['lat'], s=10)
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(100, 100))
#     figsize=(100,60))
street_map = gpd.read_file("/Users/plakshakapoor/Downloads/s_11au16/s_11au16.shp")
street_map.plot(ax=ax,alpha=0.4,color="red", figsize=(100, 100))
merge_filtered.plot(ax=ax,alpha=0.5, legend=True, markersize=1, figsize=(100, 100))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x=merge_filtered['long'], y=merge_filtered['lat'], s=0.005)
plt.show()

# %%
final_lat_long_list = merge_filtered[["long","lat"]]
# Out:
#              long        lat
# 0      -83.592091  41.304232
# 0      -83.572651  41.304232
# 0      -83.553210  41.304232
# 0      -83.611531  41.304232
# 0      -83.630972  41.286351
# ...           ...        ...
# 33143 -111.519162  40.457537
# 33143 -111.481772  40.457537
# 33143 -111.500467  40.431451
# 33143 -111.519162  40.431451
# 33143 -111.537857  40.431451
#
# [1625004 rows x 2 columns]
